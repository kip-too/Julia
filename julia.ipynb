# %%
println("Welcome to Trinidad & Tobago")
# Out:
# Welcome to Trinidad & Tobago

# %%
function welcome()
    println("Hello there, welcome to Trinidad & Tobago")
end
# Out:
# welcome (generic function with 1 method)

# %%
function greet()
    print("Hi,whats Your name?")
    name = readline()
    println("Delighted to meet you $name")
end
# Out:
# greet (generic function with 1 method)

# %%
greet()
# Out:
# Hi,whats Your name?Delighted to meet you kiptoo

# %%
b = 14
c = 25
println("The sum of $b and $c is $(b+c)")
# Out:
# The sum of 14 and 25 is 39

# %%
#area of a square
function areaOfsquare()
    print("Enter length of side:")
    s = parse(Int, readline())
    a = s * s 
    println("\nArea of square is $a")
end
# Out:
# areaOfsquare (generic function with 1 method)

# %%
function average()
    print("Enter a whole number: ")
    a = parse(Int, readline())
    print("Enter a whole number: ")
    b = parse(Int, readline())
    print("Enter a whole number: ")
    c = parse(Int, readline())
    average = round((a+b+c)/3, digits = 2)
    println("Their average is : $average")
end
# Out:
# average (generic function with 1 method)

# %%
Sys.WORD_SIZE
# Out:
# 64

# %%
typemax(Int)
# Out:
# 9223372036854775807

# %%
typemax(Int64)
# Out:
# 9223372036854775807

# %%
typemax(Int32)
# Out:
# 2147483647

# %%
str = "Data science is fun!"
str[1]
str[end]
# Out:
# '!': ASCII/Unicode U+0021 (category Po: Punctuation, other)

# %%
str[4:7]
# Out:
# "a sc"

# %%
tup1 = (3.0,9.1,0.8,1.9)
# Out:
# (3.0, 9.1, 0.8, 1.9)

# %%
typeof(tup1)
# Out:
# NTuple{4, Float64}

# %%
A4 =[1,2,3]
# Out:
# 3-element Vector{Int64}:
#  1
#  2
#  3

# %%
A6 = [80 81 82 ; 90 91 92]
# Out:
# 2×3 Matrix{Int64}:
#  80  81  82
#  90  91  92

# %%
b1 = begin
    c = 20
    d =  5
    c * d
end
# Out:
# 100

# %%
k = 1
if k == 0
    "zero"
else
    "not zero"
end
# Out:
# "not zero"

# %%
k = 11
if k%3 == 0
    0
elseif k % 3 == 1
    1
else
    2
end
# Out:
# 2

# %%
str = "julia"
# Out:
# "julia"

# %%
for s in str
    print(s)
end
# Out:
# julia

# %%
odd = [1,3,5]
even = [2,4,6]
for i in odd, j in even
    println("i*j : $(i*j)")
end
# Out:
# i*j : 2
# i*j : 4
# i*j : 6
# i*j : 6
# i*j : 12
# i*j : 18
# i*j : 10
# i*j : 20
# i*j : 30

# %%
function greet()
    print("Hi,whats Your name?")
    name = readline()
    println("Delighted to meet you $name")
end
# Out:
# greet (generic function with 1 method)

# %%
greet()
# Out:
# Hi,whats Your name?Delighted to meet you kiptoo

# %%
function areaOfTriangle()
    print("Enter the base:")
    base = readline()
    print("Enter height")
    height = readline()
    #area = 0.5 * base* height
    #println("The area of the triangle is: $area")
end
# Out:
# areaOfTriangle (generic function with 1 method)

# %%
areaOfTriangle()
# Out:
# Enter the base:Enter height
# "23"

# %%
using Plots
x = 1:10; y = rand(10);
plot(x,y, label = "my label")

# %%
using Plots
x = 0:10
y = sqrt.(x)
plot(x,y)

# %%
using Plots
x = 0:10
y = sqrt.(x)
plot(sqrt,0,10)

# %%
using Plots
plot(cos, sin, 0, 2pi,ratio=:equal)

# %%
angles = range(0, 2pi, length= 100)
plot(cos, sin ,angles, ratio=:equal)

# %%
X = range(0, 2pi, length=100)
plot([sin,cos], X)

# %%
plot([sin,cos], 0:0.1:2pi,
labels =["sin" "cos"],
linecolor = [:orange :green],
linewidth = [1,5]
)
# Out:
# ┌ Warning: Indices Base.OneTo(2) of attribute `linewidth` does not match data indices 1:63.
# └ @ Plots ~/.julia/packages/Plots/B5j7d/src/utils.jl:141
# ┌ Warning: Indices Base.OneTo(2) of attribute `linewidth` does not match data indices 1:63.
# └ @ Plots ~/.julia/packages/Plots/B5j7d/src/utils.jl:141

# %%
using Random
heights = rand(MersenneTwister(1234), 10)
bar(heights)

# %%
using Random
matrix = rand(MersenneTwister(1), 10, 10)
hm = heatmap(matrix)

# %%
plot(plot(cos),plot(sin))

# %%
plot(plot(cos),plot(sin), layout = grid(2,1))

# %%
using Plots
x = range(0, 2π, length=100);
y = sin.(x);
plt = plot(plot(x, y), scatter(x, y), bar(x, y))
# Out:
#     <div id="ada642b9-5d44-4f78-ae4d-6dbff00151aa" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['plotly'], function (Plotly) {
#
#     Plotly.newPlot('ada642b9-5d44-4f78-ae4d-6dbff00151aa', [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "y": 0.7638888888888888,
#             "title": "",
#             "len": 0.4525371828521435,
#             "x": 0.4934383202099737
#         },
#         "yaxis": "y1",
#         "x": [
#             0.0,
#             0.06346651825433926,
#             0.12693303650867852,
#             0.19039955476301776,
#             0.25386607301735703,
#             0.3173325912716963,
#             0.3807991095260355,
#             0.44426562778037476,
#             0.5077321460347141,
#             0.5711986642890533,
#             0.6346651825433925,
#             0.6981317007977318,
#             0.761598219052071,
#             0.8250647373064103,
#             0.8885312555607495,
#             0.9519977738150889,
#             1.0154642920694281,
#             1.0789308103237674,
#             1.1423973285781066,
#             1.2058638468324459,
#             1.269330365086785,
#             1.3327968833411243,
#             1.3962634015954636,
#             1.4597299198498028,
#             1.523196438104142,
#             1.5866629563584813,
#             1.6501294746128206,
#             1.7135959928671598,
#             1.777062511121499,
#             1.8405290293758383,
#             1.9039955476301778,
#             1.967462065884517,
#             2.0309285841388562,
#             2.0943951023931953,
#             2.1578616206475347,
#             2.2213281389018737,
#             2.284794657156213,
#             2.3482611754105522,
#             2.4117276936648917,
#             2.4751942119192307,
#             2.53866073017357,
#             2.6021272484279097,
#             2.6655937666822487,
#             2.729060284936588,
#             2.792526803190927,
#             2.8559933214452666,
#             2.9194598396996057,
#             2.982926357953945,
#             3.046392876208284,
#             3.1098593944626236,
#             3.1733259127169626,
#             3.236792430971302,
#             3.300258949225641,
#             3.3637254674799806,
#             3.4271919857343196,
#             3.490658503988659,
#             3.554125022242998,
#             3.6175915404973376,
#             3.6810580587516766,
#             3.744524577006016,
#             3.8079910952603555,
#             3.8714576135146945,
#             3.934924131769034,
#             3.998390650023373,
#             4.0618571682777125,
#             4.1253236865320515,
#             4.1887902047863905,
#             4.25225672304073,
#             4.3157232412950695,
#             4.3791897595494085,
#             4.4426562778037475,
#             4.506122796058087,
#             4.569589314312426,
#             4.6330558325667655,
#             4.6965223508211045,
#             4.759988869075444,
#             4.823455387329783,
#             4.886921905584122,
#             4.9503884238384614,
#             5.013854942092801,
#             5.07732146034714,
#             5.140787978601479,
#             5.204254496855819,
#             5.267721015110158,
#             5.331187533364497,
#             5.394654051618836,
#             5.458120569873176,
#             5.521587088127515,
#             5.585053606381854,
#             5.648520124636193,
#             5.711986642890533,
#             5.775453161144872,
#             5.838919679399211,
#             5.90238619765355,
#             5.96585271590789,
#             6.029319234162229,
#             6.092785752416568,
#             6.156252270670907,
#             6.219718788925247,
#             6.283185307179586
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "legendgroup": "y1",
#         "line": {
#             "color": "rgba(0, 154, 250, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             0.0,
#             0.0634239196565645,
#             0.12659245357374926,
#             0.1892512443604102,
#             0.2511479871810792,
#             0.31203344569848707,
#             0.3716624556603275,
#             0.4297949120891716,
#             0.4861967361004687,
#             0.5406408174555976,
#             0.5929079290546404,
#             0.6427876096865393,
#             0.6900790114821119,
#             0.7345917086575332,
#             0.7761464642917568,
#             0.8145759520503357,
#             0.8497254299495144,
#             0.8814533634475821,
#             0.9096319953545183,
#             0.9341478602651067,
#             0.9549022414440739,
#             0.9718115683235417,
#             0.984807753012208,
#             0.9938384644612541,
#             0.998867339183008,
#             0.9998741276738751,
#             0.9968547759519424,
#             0.9898214418809328,
#             0.9788024462147787,
#             0.9638421585599422,
#             0.9450008187146685,
#             0.9223542941045814,
#             0.8959937742913359,
#             0.8660254037844387,
#             0.8325698546347714,
#             0.7957618405308323,
#             0.7557495743542583,
#             0.712694171378863,
#             0.6667690005162916,
#             0.6181589862206055,
#             0.5670598638627709,
#             0.5136773915734063,
#             0.4582265217274105,
#             0.4009305354066136,
#             0.3420201433256689,
#             0.28173255684142967,
#             0.2203105327865408,
#             0.1580013959733499,
#             0.09505604330418288,
#             0.031727933498067656,
#             -0.031727933498067414,
#             -0.09505604330418263,
#             -0.15800139597334964,
#             -0.22031053278654056,
#             -0.2817325568414294,
#             -0.34202014332566866,
#             -0.4009305354066134,
#             -0.4582265217274103,
#             -0.5136773915734061,
#             -0.5670598638627706,
#             -0.6181589862206053,
#             -0.6667690005162915,
#             -0.7126941713788629,
#             -0.7557495743542582,
#             -0.7957618405308321,
#             -0.8325698546347713,
#             -0.8660254037844385,
#             -0.895993774291336,
#             -0.9223542941045814,
#             -0.9450008187146683,
#             -0.9638421585599419,
#             -0.9788024462147787,
#             -0.9898214418809327,
#             -0.9968547759519423,
#             -0.9998741276738751,
#             -0.998867339183008,
#             -0.9938384644612541,
#             -0.9848077530122081,
#             -0.9718115683235419,
#             -0.9549022414440739,
#             -0.9341478602651068,
#             -0.9096319953545186,
#             -0.881453363447582,
#             -0.8497254299495144,
#             -0.8145759520503358,
#             -0.7761464642917572,
#             -0.7345917086575331,
#             -0.690079011482112,
#             -0.6427876096865396,
#             -0.5929079290546408,
#             -0.5406408174555974,
#             -0.4861967361004688,
#             -0.4297949120891719,
#             -0.3716624556603281,
#             -0.31203344569848707,
#             -0.2511479871810794,
#             -0.18925124436041063,
#             -0.12659245357374993,
#             -0.06342391965656452,
#             -2.4492935982947064e-16
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "y": 0.7638888888888888,
#             "title": "",
#             "len": 0.4525371828521435,
#             "x": 0.9934383202099737
#         },
#         "yaxis": "y2",
#         "x": [
#             0.0,
#             0.06346651825433926,
#             0.12693303650867852,
#             0.19039955476301776,
#             0.25386607301735703,
#             0.3173325912716963,
#             0.3807991095260355,
#             0.44426562778037476,
#             0.5077321460347141,
#             0.5711986642890533,
#             0.6346651825433925,
#             0.6981317007977318,
#             0.761598219052071,
#             0.8250647373064103,
#             0.8885312555607495,

# %%
using Plots

# %%
function  plot_frame(angle)
    scatter(
        [cos(angle)],
        [sin(angle)],
        ratio=:equal,
        xlims=(-1.5,1.5), ylims=(-1.5,1.5),
        legend=:none
    )
end
# Out:
# plot_frame (generic function with 1 method)

# %%
anim = Animation()
# Out:
# Animation("/tmp/jl_YnMCmG", String[])

# %%
using RDatasets
rds = RDatasets.datasets()
filter(x -> occursin("crab",x[:Dataset]), rds)
crabs = dataset("MASS","crabs")
print(crabs[1:5, :])
# Out:
# 5×8 DataFrame
#  Row │ Sp    Sex   Index  FL       RW       CL       CW       BD
#      │ Cat…  Cat…  Int32  Float64  Float64  Float64  Float64  Float64
# ─────┼────────────────────────────────────────────────────────────────
#    1 │ B     M         1      8.1      6.7     16.1     19.0      7.0
#    2 │ B     M         2      8.8      7.7     18.1     20.8      7.4
#    3 │ B     M         3      9.2      7.8     19.0     22.4      7.7
#    4 │ B     M         4      9.6      7.9     20.1     23.1      8.2
#    5 │ B     M         5      9.8      8.0     20.3     23.0      8.2
